# %% [markdown]
# ##### Now we know which model to apply for our analysis. Hence, we actually start the model evaluation and refinement by testing and training it over and over again

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('module_5_auto.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses         make  \
# 0           0             0          3                122  alfa-romero
# 1           1             1          3                122  alfa-romero
#
#   aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0        std          two  convertible          rwd           front  ...
# 1        std          two  convertible          rwd           front  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# 0                9.0       111.0    5000.0        21           27  13495.0
# 1                9.0       111.0    5000.0        21           27  16500.0
#
#   city-L/100km  horsepower-binned diesel  gas
# 0    11.190476             Medium      0    1
# 1    11.190476             Medium      0    1
#
# [2 rows x 31 columns]

# %%
df=df._get_numeric_data()
#let us take only the numeric data

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses  wheel-base  \
# 0           0             0          3                122        88.6
# 1           1             1          3                122        88.6
# 2           2             2          1                122        94.5
# 3           3             3          2                164        99.8
# 4           4             4          2                164        99.4
#
#      length     width  height  curb-weight  engine-size  ...  stroke  \
# 0  0.811148  0.890278    48.8         2548          130  ...    2.68
# 1  0.811148  0.890278    48.8         2548          130  ...    2.68
# 2  0.822681  0.909722    52.4         2823          152  ...    3.47
# 3  0.848630  0.919444    54.3         2337          109  ...    3.40
# 4  0.848630  0.922222    54.3         2824          136  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %%
#The libraries we will be using for plotting

from ipywidgets import interact, interactive, fixed, interact_manual

# %%
#the functions for plotting are

def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')

    plt.show()
    plt.close()

def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %% [markdown]
# <h2 id="ref1">Part 1: Training and Testing</h2>
#
# <p>An important step in testing your model is to split your data into training and testing data. We will place the target data <b>price</b> in a separate dataframe <b>y_data</b>:</p>

# %%
y_data = df['price']

# %%
y_data
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, Length: 201, dtype: float64

# %%
x_data = df.drop('price',axis=1)
#we drop the price data in dataframe x_data. Hence the
#label is removed and the dataframe has only the features

# %%
x_data
# Out:
#      Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses  wheel-base  \
# 0             0             0          3                122        88.6
# 1             1             1          3                122        88.6
# 2             2             2          1                122        94.5
# 3             3             3          2                164        99.8
# 4             4             4          2                164        99.4
# ..          ...           ...        ...                ...         ...
# 196         196           196         -1                 95       109.1
# 197         197           197         -1                 95       109.1
# 198         198           198         -1                 95       109.1
# 199         199           199         -1                 95       109.1
# 200         200           200         -1                 95       109.1
#
#        length     width  height  curb-weight  engine-size  bore  stroke  \
# ...

# %%
#Now we have to split our data into training and testing data

from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)


print("number of test samples :", x_test.shape[0]) #this tells us the number of rows, hence the sample size
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 21
# number of training samples: 180

# %% [markdown]
# The <b>test_size</b> parameter sets the proportion of data that is split into the testing set. In the above, the testing set is 10% of the total dataset.

# %%
x_test.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses  wheel-base  \
# 97           97            97          0                106        97.2
# 117         117           117          1                154        93.7
# 59           59            59          0                115        98.8
# 35           35            35          0                 78        96.5
# 165         165           165          2                134        98.4
#
#        length     width  height  curb-weight  engine-size  bore  stroke  \
# 97   0.833253  0.905556    54.7         2302          120  3.33    3.47
# 117  0.755887  0.886111    50.6         1967           90  2.97    3.23
# 59   0.854397  0.923611    55.5         2410          122  3.39    3.39
# 35   0.754926  0.887500    58.3         2024           92  2.92    3.41
# 165  0.846708  0.911111    52.0         2551          146  3.62    3.50
#
#      compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  \
# ...

# %%
#let us import the linear regression module

from sklearn.linear_model import LinearRegression

# %%
lre = LinearRegression()

# %%
lre.fit(x_train[['horsepower']],y_train)
#we fit the model using the 'horsepower' feature
# Out:
# LinearRegression()

# %%
#calculate the R-squared on the test data

lre.score(x_test[['horsepower']],y_test)
# Out:
# 0.36358755750788263

# %%
lre.score(x_train[['horsepower']],y_train)
# Out:
# 0.6619724197515104

# %% [markdown]
# We can see the R^2 is much smaller using the test data compared to the training data.

# %% [markdown]
# Sometimes you do not have sufficient testing data; as a result, you may want to perform cross-validation. Let's go over several methods that you can use for cross-validation.

# %% [markdown]
# <h2>Cross-Validation Score</h2>

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# We input the object, the feature ("horsepower"), and the target data (y_data). The parameter 'cv' determines the number of folds. In this case, it is 4.

# %%
Rcross = cross_val_score(lre, x_data[['horsepower']], y_data, cv=4)
